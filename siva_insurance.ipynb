# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv("train-1574429526318.csv",sep = "," , header = 0, na_values = ("","?"))
test = pd.read_csv("test-1574429501088.csv",sep = "," , header = 0, na_values = ("","?"))

# %%
train.head()
# Out:
#    CustomerID  Customer.Lifetime.Value Coverage             Education  \
# 0        5917              7824.372789    Basic              Bachelor
# 1        2057              8005.964669    Basic               College
# 2        4119              8646.504109    Basic  High School or Below
# 3        1801              9294.088719    Basic               College
# 4        9618              5595.971365    Basic              Bachelor
#
#   EmploymentStatus Gender   Income Location.Geo Location.Code Marital.Status  \
# 0       Unemployed      F      0.0    17.7,77.7         Urban        Married
# 1         Employed      M  63357.0    28.8,76.6      Suburban        Married
# 2         Employed      F  64125.0    21.6,88.4         Urban        Married
# 3         Employed      M  67544.0      19,72.5      Suburban        Married
# 4          Retired      F  19651.0    19.1,74.7      Suburban        Married
#
#    ...  Months.Since.Policy.Inception  Number.of.Open.Complaints  \
# ...

# %%
train.describe(include = 'all')
# Out:
#           CustomerID  Customer.Lifetime.Value Coverage Education  \
# count    9806.000000              9806.000000     8881      9677
# unique           NaN                      NaN        3         5
# top              NaN                      NaN    Basic  Bachelor
# freq             NaN                      NaN     5361      2934
# mean     5778.381807              7998.047015      NaN       NaN
# std      3343.286093              6848.055899      NaN       NaN
# min         1.000000              1898.007675      NaN       NaN
# 25%      2879.250000              4013.949039      NaN       NaN
# 50%      5783.000000              5780.182197      NaN       NaN
# 75%      8678.750000              8960.280213      NaN       NaN
# max     11573.000000             83325.381190      NaN       NaN
#
#        EmploymentStatus Gender        Income Location.Geo Location.Code  \
# count              9688   9677   9688.000000         9806          9687
# ...

# %%
train.shape,test.shape
# Out:
# ((9806, 22), (1767, 21))

# %%
train.isnull().sum()
# Out:
# CustomerID                         0
# Customer.Lifetime.Value            0
# Coverage                         925
# Education                        129
# EmploymentStatus                 118
# Gender                           129
# Income                           118
# Location.Geo                       0
# Location.Code                    119
# Marital.Status                   129
# Monthly.Premium.Auto             794
# Months.Since.Last.Claim            0
# Months.Since.Policy.Inception      0
# Number.of.Open.Complaints        818
# Number.of.Policies               121
# Policy.Type                      891
# Policy                           121
# Renew.Offer.Type                 128
# Sales.Channel                    128
# Total.Claim.Amount                 0
# Vehicle.Class                    126
# Vehicle.Size                     126
# dtype: int64

# %%
train.dtypes
# Out:
# CustomerID                         int64
# Customer.Lifetime.Value          float64
# Coverage                          object
# Education                         object
# EmploymentStatus                  object
# Gender                            object
# Income                           float64
# Location.Geo                      object
# Location.Code                     object
# Marital.Status                    object
# Monthly.Premium.Auto             float64
# Months.Since.Last.Claim            int64
# Months.Since.Policy.Inception      int64
# Number.of.Open.Complaints        float64
# Number.of.Policies               float64
# Policy.Type                       object
# Policy                            object
# Renew.Offer.Type                  object
# Sales.Channel                     object
# Total.Claim.Amount               float64
# Vehicle.Class                     object
# Vehicle.Size                     float64
# dtype: object

# %%
import seaborn as sns
sns.barplot(x='Coverage',y='Customer.Lifetime.Value',data = train)

# %%
sns.barplot(x='Number.of.Policies',y='Customer.Lifetime.Value',data = train)

# %%
sns.barplot(x='Location.Code',y='Customer.Lifetime.Value',data = train)

# %%
sns.barplot(x='Number.of.Open.Complaints',y='Customer.Lifetime.Value',data = train)

# %%
sns.barplot(x='EmploymentStatus',y='Customer.Lifetime.Value',data = train)

# %%
sns.barplot(x='Monthly.Premium.Auto',y='Customer.Lifetime.Value',data = train)

# %%
sns.barplot(x='Policy.Type',y='Customer.Lifetime.Value',data = train)

# %%
import matplotlib.pylab as plt
sns.boxplot(train.Income,orient='v')

# %%
sns.barplot(x='Number.of.Open.Complaints',y='Customer.Lifetime.Value',data = train)

# %%
import matplotlib.pyplot as plt
sns.pairplot(train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
train['Coverage'] = pd.Categorical(train.Coverage,categories=["Basic","Extended","Premium","Other"],ordered=False)
train.Coverage.fillna("Other",inplace = True)

# %%
sns.barplot(x='Coverage',y='Customer.Lifetime.Value',data = train)

# %%
sns.barplot(x='Policy.Type',y='Customer.Lifetime.Value',data = train)

# %%
sns.barplot(x='Policy',y='Customer.Lifetime.Value',data = train)

# %%
sns.barplot(x='Number.of.Open.Complaints',y='Customer.Lifetime.Value',data = train)

# %%
sns.barplot(x='Policy.Type',y='Customer.Lifetime.Value',data = train,estimator = sum)

# %%
train.head(2)
# Out:
#    CustomerID  Customer.Lifetime.Value Coverage Education EmploymentStatus  \
# 0        5917              7824.372789    Basic  Bachelor       Unemployed
# 1        2057              8005.964669    Basic   College         Employed
#
#   Gender   Income Location.Geo Location.Code Marital.Status  ...  \
# 0      F      0.0    17.7,77.7         Urban        Married  ...
# 1      M  63357.0    28.8,76.6      Suburban        Married  ...
#
#    Months.Since.Policy.Inception  Number.of.Open.Complaints  \
# 0                             33                        NaN
# 1                             42                        0.0
#
#    Number.of.Policies    Policy.Type       Policy Renew.Offer.Type  \
# 0                 2.0  Personal Auto  Personal L2           Offer2
# 1                 5.0  Personal Auto  Personal L2           Offer2
#
#   Sales.Channel Total.Claim.Amount  Vehicle.Class  Vehicle.Size
# 0        Branch         267.214383  Four-Door Car           2.0
# ...

# %%
train.drop(['CustomerID','Gender','Location.Geo','Location.Code','Education','Gender','Policy','Marital.Status','Sales.Channel','Vehicle.Size'],axis = 1, inplace = True)

# %%
test.drop(['CustomerID','Gender','Location.Geo','Location.Code','Education','Gender','Policy','Marital.Status','Sales.Channel','Vehicle.Size'],axis = 1, inplace = True)

# %%
test.isnull().sum()
# Out:
# Coverage                           0
# EmploymentStatus                   0
# Income                           239
# Monthly.Premium.Auto              72
# Months.Since.Last.Claim            0
# Months.Since.Policy.Inception      0
# Number.of.Open.Complaints          0
# Number.of.Policies                 0
# Policy.Type                       42
# Renew.Offer.Type                   0
# Total.Claim.Amount                 0
# Vehicle.Class                      0
# dtype: int64

# %%
train['Policy.Type'] = pd.Categorical(train['Policy.Type'],categories=["Personal Auto","Corporate Auto","Special Auto","Other Auto"],ordered=False)

# %%
train['Policy.Type'].fillna("Other Auto",inplace = True)

# %%
test['Policy.Type'] = pd.Categorical(test['Policy.Type'],categories=["Personal Auto","Corporate Auto","Special Auto","Other Auto"],ordered=False)

# %%
test['Policy.Type'].fillna("Other Auto",inplace = True)

# %%
train.isnull().sum()
# Out:
# Customer.Lifetime.Value            0
# Coverage                           0
# EmploymentStatus                 118
# Income                           118
# Monthly.Premium.Auto             794
# Months.Since.Last.Claim            0
# Months.Since.Policy.Inception      0
# Number.of.Open.Complaints        818
# Number.of.Policies               121
# Policy.Type                        0
# Renew.Offer.Type                 128
# Total.Claim.Amount                 0
# Vehicle.Class                    126
# dtype: int64

# %%
train['Monthly.Premium.Auto'].value_counts()
# Out:
# 65.0     348
# 71.0     308
# 73.0     298
# 66.0     288
# 67.0     286
#         ...
# 252.0      1
# 230.0      1
# 237.0      1
# 238.0      1
# 253.0      1
# Name: Monthly.Premium.Auto, Length: 191, dtype: int64

# %%
train['Monthly.Premium.Auto'].describe()
# Out:
# count    9012.000000
# mean       93.340657
# std        34.417763
# min        61.000000
# 25%        68.750000
# 50%        83.000000
# 75%       109.000000
# max       297.000000
# Name: Monthly.Premium.Auto, dtype: float64

# %%
train['Monthly.Premium.Auto'].shape
# Out:
# (9806,)

# %%
from sklearn.impute import SimpleImputer
imputer  = SimpleImputer(strategy = "mean")
train['Monthly.Premium.Auto'] = imputer.fit_transform(pd.DataFrame(train['Monthly.Premium.Auto']))

# %%
test['Monthly.Premium.Auto'] = imputer.transform(pd.DataFrame(test['Monthly.Premium.Auto']))

# %%
train.Income.describe()
# Out:
# count     9688.000000
# mean     37511.054604
# std      30292.974468
# min          0.000000
# 25%          0.000000
# 50%      33767.500000
# 75%      62018.000000
# max      99981.000000
# Name: Income, dtype: float64

# %%
imputer  = SimpleImputer(strategy = "mean")
train['Income'] = imputer.fit_transform(pd.DataFrame(train['Income']))

# %%
test['Income'] = imputer.transform(pd.DataFrame(test['Income']))

# %%
train['Number.of.Open.Complaints'].fillna(train['Number.of.Open.Complaints'].mode()[0],inplace=True)

# %%
train.isnull().sum()
# Out:
# Customer.Lifetime.Value            0
# Coverage                           0
# EmploymentStatus                 118
# Income                             0
# Monthly.Premium.Auto               0
# Months.Since.Last.Claim            0
# Months.Since.Policy.Inception      0
# Number.of.Open.Complaints          0
# Number.of.Policies               121
# Policy.Type                        0
# Renew.Offer.Type                 128
# Total.Claim.Amount                 0
# Vehicle.Class                    126
# dtype: int64

# %%
train['EmploymentStatus'].fillna(train['EmploymentStatus'].mode()[0],inplace=True)
test['EmploymentStatus'].fillna(train['EmploymentStatus'].mode()[0],inplace=True)

# %%
train['Number.of.Policies'].fillna(train['Number.of.Policies'].mode()[0],inplace=True)
train['Renew.Offer.Type'].fillna(train['Renew.Offer.Type'].mode()[0],inplace=True)
train['Vehicle.Class'].fillna(train['Vehicle.Class'].mode()[0],inplace=True)

# %%
test.isnull().sum()
# Out:
# Coverage                         0
# EmploymentStatus                 0
# Income                           0
# Monthly.Premium.Auto             0
# Months.Since.Last.Claim          0
# Months.Since.Policy.Inception    0
# Number.of.Open.Complaints        0
# Number.of.Policies               0
# Policy.Type                      0
# Renew.Offer.Type                 0
# Total.Claim.Amount               0
# Vehicle.Class                    0
# dtype: int64

# %%
x = train.copy().drop("Customer.Lifetime.Value",axis=1)
y = train["Customer.Lifetime.Value"]

# %%
import seaborn as sns
sns.distplot(pd.DataFrame(y))
print("Skewness: %f" % pd.DataFrame(y).skew())
print("Kurtosis: %f" % pd.DataFrame(y).kurt())
# Out:
# Skewness: 3.027343
# Kurtosis: 13.807141

# %%
import seaborn as sns
sns.distplot(pd.DataFrame(np.log(y)))
print("Skewness: %f" % pd.DataFrame(np.log(y)).skew())
print("Kurtosis: %f" % pd.DataFrame(np.log(y)).kurt())
# Out:
# Skewness: 0.574144
# Kurtosis: 0.078095

# %%
x.head()
# Out:
#   Coverage EmploymentStatus   Income  Monthly.Premium.Auto  \
# 0    Basic       Unemployed      0.0                  67.0
# 1    Basic         Employed  63357.0                 101.0
# 2    Basic         Employed  64125.0                 108.0
# 3    Basic         Employed  67544.0                 116.0
# 4    Basic          Retired  19651.0                  72.0
#
#    Months.Since.Last.Claim  Months.Since.Policy.Inception  \
# 0                        2                             33
# 1                       26                             42
# 2                        3                             44
# 3                        2                             15
# 4                        3                             68
#
#    Number.of.Open.Complaints  Number.of.Policies     Policy.Type  \
# 0                        0.0                 2.0   Personal Auto
# 1                        0.0                 5.0   Personal Auto
# ...

# %%
x.shape,test.shape
# Out:
# ((9806, 12), (1767, 12))

# %%
x.dtypes
# Out:
# Coverage                         category
# EmploymentStatus                   object
# Income                            float64
# Monthly.Premium.Auto              float64
# Months.Since.Last.Claim             int64
# Months.Since.Policy.Inception       int64
# Number.of.Open.Complaints         float64
# Number.of.Policies                float64
# Policy.Type                      category
# Renew.Offer.Type                   object
# Total.Claim.Amount                float64
# Vehicle.Class                      object
# dtype: object

# %%
x.head(2)
# Out:
#   Coverage EmploymentStatus   Income  Monthly.Premium.Auto  \
# 0    Basic       Unemployed      0.0                  67.0
# 1    Basic         Employed  63357.0                 101.0
#
#    Months.Since.Last.Claim  Months.Since.Policy.Inception  \
# 0                        2                             33
# 1                       26                             42
#
#    Number.of.Open.Complaints  Number.of.Policies    Policy.Type  \
# 0                        0.0                 2.0  Personal Auto
# 1                        0.0                 5.0  Personal Auto
#
#   Renew.Offer.Type  Total.Claim.Amount  Vehicle.Class
# 0           Offer2          267.214383  Four-Door Car
# 1           Offer2          565.508572            SUV

# %%
x.isnull().sum()
# Out:
# Coverage                         0
# EmploymentStatus                 0
# Income                           0
# Monthly.Premium.Auto             0
# Months.Since.Last.Claim          0
# Months.Since.Policy.Inception    0
# Number.of.Open.Complaints        0
# Number.of.Policies               0
# Policy.Type                      0
# Renew.Offer.Type                 0
# Total.Claim.Amount               0
# Vehicle.Class                    0
# dtype: int64

# %%
for cols in ["Coverage","EmploymentStatus","Policy.Type","Renew.Offer.Type","Vehicle.Class"]:
    x[cols] = x[cols].astype('category')

# %%
for cols in ["Coverage","EmploymentStatus","Policy.Type","Renew.Offer.Type","Vehicle.Class"]:
    test[cols] = test[cols].astype('category')

# %%
test.dtypes
# Out:
# Coverage                         category
# EmploymentStatus                 category
# Income                            float64
# Monthly.Premium.Auto              float64
# Months.Since.Last.Claim             int64
# Months.Since.Policy.Inception       int64
# Number.of.Open.Complaints           int64
# Number.of.Policies                  int64
# Policy.Type                      category
# Renew.Offer.Type                 category
# Total.Claim.Amount                float64
# Vehicle.Class                    category
# dtype: object

# %%
x.describe(include='all')
# Out:
#        Coverage EmploymentStatus        Income  Monthly.Premium.Auto  \
# count      9806             9806   9806.000000           9806.000000
# unique        4                5           NaN                   NaN
# top       Basic         Employed           NaN                   NaN
# freq       5361             6138           NaN                   NaN
# mean        NaN              NaN  37511.054604             93.340657
# std         NaN              NaN  30110.139644             32.994788
# min         NaN              NaN      0.000000             61.000000
# 25%         NaN              NaN      0.000000             69.000000
# 50%         NaN              NaN  34430.000000             88.000000
# 75%         NaN              NaN  61647.000000            107.000000
# max         NaN              NaN  99981.000000            297.000000
#
#         Months.Since.Last.Claim  Months.Since.Policy.Inception  \
# count               9806.000000                    9806.000000
# ...

# %%
from sklearn.model_selection import train_test_split
#for splitting the data in train and test
x_train, x_val, y_train, y_val = train_test_split(x,y,test_size = 0.2, random_state = 200)

# %%
x_train.shape, x_val.shape, y_train.shape, y_val.shape
# Out:
# ((7844, 12), (1962, 12), (7844,), (1962,))

# %%
x_train.dtypes
# Out:
# Coverage                         category
# EmploymentStatus                 category
# Income                            float64
# Monthly.Premium.Auto              float64
# Months.Since.Last.Claim             int64
# Months.Since.Policy.Inception       int64
# Number.of.Open.Complaints         float64
# Number.of.Policies                float64
# Policy.Type                      category
# Renew.Offer.Type                 category
# Total.Claim.Amount                float64
# Vehicle.Class                    category
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
for cols in ["Coverage","EmploymentStatus","Policy.Type","Renew.Offer.Type"]:
    x_train[cols] = x_train[cols].cat.codes
    x_val[cols] = x_val[cols].cat.codes
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
for cols in ["Coverage","EmploymentStatus","Policy.Type","Renew.Offer.Type"]:
    test[cols] = test[cols].cat.codes

# %%
test.dtypes
# Out:
# Coverage                             int8
# EmploymentStatus                     int8
# Income                            float64
# Monthly.Premium.Auto              float64
# Months.Since.Last.Claim             int64
# Months.Since.Policy.Inception       int64
# Number.of.Open.Complaints           int64
# Number.of.Policies                  int64
# Policy.Type                          int8
# Renew.Offer.Type                     int8
# Total.Claim.Amount                float64
# Vehicle.Class                    category
# dtype: object

# %%
x_train.head(4)
# Out:
#       Coverage  EmploymentStatus   Income  Monthly.Premium.Auto  \
# 8311         0                 1  25285.0                 114.0
# 919          0                 1  97657.0                  71.0
# 1916         3                 1  28663.0                  66.0
# 3935         0                 4      0.0                  74.0
#
#       Months.Since.Last.Claim  Months.Since.Policy.Inception  \
# 8311                       12                             84
# 919                         2                             19
# 1916                        1                             56
# 3935                        7                             20
#
#       Number.of.Open.Complaints  Number.of.Policies  Policy.Type  \
# 8311                        0.0                 2.0            0
# 919                         0.0                 8.0            0
# 1916                        0.0                 1.0            1
# 3935                        0.0                 1.0            0
#
# ...

# %%
cols_to_transform = x_train.select_dtypes(include=['category']).columns
x_train = pd.get_dummies(columns=cols_to_transform, data=x_train, prefix=cols_to_transform, prefix_sep="_", drop_first=True)

# %%
cols_to_transform = x_val.select_dtypes(include=['category']).columns
x_val = pd.get_dummies(columns=cols_to_transform, data=x_val, prefix=cols_to_transform, prefix_sep="_", drop_first=True)

# %%
cols_to_transform = test.select_dtypes(include=['category']).columns
test = pd.get_dummies(columns=cols_to_transform, data=test, prefix=cols_to_transform, prefix_sep="_", drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b63e963b27ef> in <module>
# ----> 1 cols_to_transform = test.select_dtypes(include=['category']).columns
#       2 test = pd.get_dummies(columns=cols_to_transform, data=test, prefix=cols_to_transform, prefix_sep="_", drop_first=True)
#
# NameError: name 'test' is not defined

# %%
x_train.shape
# Out:
# (7844, 16)

# %%
x_train.head()
# Out:
#       Coverage  EmploymentStatus   Income  Monthly.Premium.Auto  \
# 8311         0                 1  25285.0                 114.0
# 919          0                 1  97657.0                  71.0
# 1916         3                 1  28663.0                  66.0
# 3935         0                 4      0.0                  74.0
# 131          1                 1  57844.0                  85.0
#
#       Months.Since.Last.Claim  Months.Since.Policy.Inception  \
# 8311                       12                             84
# 919                         2                             19
# 1916                        1                             56
# 3935                        7                             20
# 131                        16                             31
#
#       Number.of.Open.Complaints  Number.of.Policies  Policy.Type  \
# 8311                        0.0                 2.0            0
# 919                         0.0                 8.0            0
# ...

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
for cols in ['Income','Monthly.Premium.Auto','Months.Since.Last.Claim','Months.Since.Policy.Inception','Number.of.Policies','Total.Claim.Amount']:
    scale_fit=scale.fit(pd.DataFrame(x_train[cols]))
    x_train[cols] = scale_fit.transform(pd.DataFrame(x_train[cols]))

# %%
for cols in ['Income','Monthly.Premium.Auto','Months.Since.Last.Claim','Months.Since.Policy.Inception','Number.of.Policies','Total.Claim.Amount']:
    scale_fit=scale.fit(pd.DataFrame(x_val[cols]))
    x_val[cols] = scale_fit.transform(pd.DataFrame(x_val[cols]))

# %%
for cols in ['Income','Monthly.Premium.Auto','Months.Since.Last.Claim','Months.Since.Policy.Inception','Number.of.Policies','Total.Claim.Amount']:
    scale_fit=scale.fit(pd.DataFrame(test[cols]))
    test[cols] = scale_fit.transform(pd.DataFrame(test[cols]))

# %%
x_train.head()
# Out:
#       Coverage  EmploymentStatus    Income  Monthly.Premium.Auto  \
# 8311         0                 1 -0.406027              0.631321
# 919          0                 1  1.997406             -0.682154
# 1916         3                 1 -0.293846             -0.834884
# 3935         0                 4 -1.245728             -0.590517
# 131          1                 1  0.675239             -0.254511
#
#       Months.Since.Last.Claim  Months.Since.Policy.Inception  \
# 8311                -0.317605                       1.275422
# 919                 -1.313764                      -1.045621
# 1916                -1.413380                       0.275588
# 3935                -0.815684                      -1.009913
# 131                  0.080859                      -0.617121
#
#       Number.of.Open.Complaints  Number.of.Policies  Policy.Type  \
# 8311                        0.0           -0.391671            0
# 919                         0.0            2.109494            0
# ...

# %%
test.head()
# Out:
#    Coverage  EmploymentStatus    Income  Monthly.Premium.Auto  \
# 0         0                 1  0.006983             -0.605726
# 1         1                 1 -0.547182             -0.017955
# 2         2                 1  1.231206              0.481651
# 3         0                 1 -0.702580             -0.870223
# 4         1                 0 -1.101310             -0.429394
#
#    Months.Since.Last.Claim  Months.Since.Policy.Inception  \
# 0                -0.296298                      -0.124761
# 1                 0.193925                      -1.448698
# 2                -0.590432                       1.234958
# 3                -0.296298                       0.089931
# 4                -0.688477                       0.054149
#
#    Number.of.Open.Complaints  Number.of.Policies  Policy.Type  \
# 0                          0           -0.838652            0
# 1                          0            2.093312            2
# ...

# %% [markdown]
# # Model Building

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
linear = linear_model.LinearRegression()
linear.fit(x_train, y_train)

preds_train_lr = linear.predict(x_train)
preds_val_lr = linear.predict(x_val)

lr_mse_train = mean_squared_error(preds_train_lr, y_train)
lr_rmse_train = np.sqrt(lr_mse_train)
print("Linear Regression MSE on train: %.4f" %lr_mse_train)
print('Linear Regression RMSE on train: %.4f' % lr_rmse_train)

lr_mse_val = mean_squared_error(preds_val_lr, y_val)
lr_rmse_val = np.sqrt(lr_mse_val)
print("Linear Regression MSE on val: %.4f" %lr_mse_val)
print('Linear Regression RMSE on val: %.4f' % lr_rmse_val)
# Out:
# Linear Regression MSE on train: 39243813.5648
# Linear Regression RMSE on train: 6264.4883
# Linear Regression MSE on val: 39601030.0278
# Linear Regression RMSE on val: 6292.9349

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
linear = linear_model.LinearRegression()
linear.fit(x_train, np.log(y_train))

preds_train_lr_log = linear.predict(x_train)
preds_val_lr_log = linear.predict(x_val)

lr_mse_train_log = mean_squared_error(preds_train_lr_log, np.log(y_train))
lr_rmse_train_log = np.sqrt(lr_mse_train_log)
print("Linear Regression MSE on train with log transformation: %.4f" %lr_mse_train_log)
print('Linear Regression RMSE on train with log transformation: %.4f' % lr_rmse_train_log)

lr_mse_val_log = mean_squared_error(preds_val_lr_log, np.log(y_val))
lr_rmse_val_log = np.sqrt(lr_mse_val_log)
print("Linear Regression MSE on val with log transformation: %.4f" %lr_mse_val_log)
print('Linear Regression RMSE on val with log transformation: %.4f' % lr_rmse_val_log)
# Out:
# Linear Regression MSE on train with log transformation: 0.3167
# Linear Regression RMSE on train with log transformation: 0.5627
# Linear Regression MSE on val with log transformation: 0.3323
# Linear Regression RMSE on val with log transformation: 0.5764

# %%
MAPE_train=np.mean(np.abs(y_train - preds_train_lr)/(y_train))
print(MAPE_train)

MAPE_val=np.mean(np.abs(y_val - preds_val_lr)/(y_val))
print(MAPE_val)
# Out:
# 0.5928053887471243
# 0.5847108873892986

# %%
MAPE_train_log=np.mean(np.abs(np.log(y_train) - preds_train_lr_log)/np.log(y_train))
print(MAPE_train_log)

MAPE_val_log=np.mean(np.abs(np.log(y_val) - preds_val_lr_log)/np.log(y_val))
print(MAPE_val_log)
# Out:
# 0.049423657016282097
# 0.05005509261646108

# %%
from sklearn.metrics import mean_squared_error
from sklearn.tree import export_graphviz,DecisionTreeRegressor
DTR = DecisionTreeRegressor(random_state=42)
DTR.fit(x_train, np.log(y_train))

preds_train_DT = DTR.predict(x_train)
preds_val_DT = DTR.predict(x_val)

DT_mse_train = mean_squared_error(preds_train_DT, y_train)
DT_rmse_train = np.sqrt(DT_mse_train)
DT_mse_val = mean_squared_error(preds_val_DT, y_val)
DT_rmse_val = np.sqrt(DT_mse_val)

print("Decision Tree Regressor MSE on train: %.4f" %DT_mse_train)
print('Decision Tree Regressor RMSE on train: %.4f' % DT_rmse_train)
print("Decision Tree Regressor MSE on val: %.4f" %DT_mse_val)
print('Decision Tree Regressor RMSE on val: %.4f' % DT_rmse_val)
# Out:
# Decision Tree Regressor MSE on train: 110124222.4077
# Decision Tree Regressor RMSE on train: 10494.0089
# Decision Tree Regressor MSE on val: 113062961.6836
# Decision Tree Regressor RMSE on val: 10633.1069

# %%
from xgboost import XGBRegressor
XGB = XGBRegressor(colsample_bytree=0.6, max_depth = 10,n_estimators = 200,random_state=0,alpha=0.1)
XGB.fit(x_train, y_train)

preds_train_XG = XGB.predict(x_train)
preds_val_XG = XGB.predict(x_val)
preds_test_XG = XGB.predict(test)

XG_mse_train = mean_squared_error(preds_train_XG, y_train)
XG_rmse_train = np.sqrt(XG_mse_train)

print("XGB Regressor MSE on val: %.4f" %XG_mse_train)
print('XGB Regressor RMSE on val: %.4f' % XG_rmse_train)

XG_mse_val = mean_squared_error(preds_val_XG, y_val)
XG_rmse_val = np.sqrt(XG_mse_val)

print("XGB Regressor MSE on val: %.4f" %XG_mse_val)
print('XGB Regressor RMSE on val: %.4f' % XG_rmse_val)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [18:53:19] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB Regressor MSE on val: 365161.0792
# XGB Regressor RMSE on val: 604.2856
# XGB Regressor MSE on val: 17549193.5273
# XGB Regressor RMSE on val: 4189.1758

# %%
MAPE_train=np.mean(np.abs(y_train - preds_train_DT)/(y_train))
print(MAPE_train)

MAPE_val=np.mean(np.abs(y_val - preds_val_DT)/(y_val))
print(MAPE_val)
# Out:
# 1.9538430762210343e-12
# 0.17578149611768978

# %%
MAPE_train=np.mean(np.abs(y_train - preds_train_XG)/(y_train))
print(MAPE_train)

MAPE_val=np.mean(np.abs(y_val - preds_val_XG)/(y_val))
print(MAPE_val)
# Out:
# 0.033549209200026534
# 0.20116482734928148
